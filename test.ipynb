# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

fig, ax = plt.subplots()
line, = ax.plot([])     # A tuple unpacking to unpack the only plot
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(-1.1, 1.1)

def animate(frame_num):
    x = 0
    y = np.sin(x + 2*np.pi * frame_num/100)
    line.set_data(x, y)
    return line

anim = FuncAnimation(fig, animate, frames=100, interval=5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# C:\Users\rafe9\AppData\Local\Temp\ipykernel_17808\3244860383.py:15: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
